# %%
#EPR Spectra

# %% [markdown]
# Data Loading and Sample Preparation:
# Import data on ferumoxytol (FMX) nanoparticle concentrations and radiation doses. Prepare FMX samples in different concentrations (50 nM to 1 µM) in water or xylenol orange solution.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Radiation Exposure:
# Irradiate samples using a 37Cesium source with a dose rate of 0.6 Gy min−1. Apply various radiation doses, focusing on the range up to 20 Gy where the response is linear.

# %% [markdown]
# Electron Paramagnetic Resonance (EPR) Spectroscopy:
# Perform EPR spectroscopy to assess FMX oxidation. Measure the peak-to-peak signal intensity of the EPR spectra at g = 2 for various FMX concentrations and radiation doses.
#
# Data Analysis:
# Process EPR data to quantify changes in signal intensity. Calculate the relative change in EPR signal for different FMX concentrations and radiation doses.

# %%
#0 Gy *
Gy_0 = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/150nm_0Gy_Gain5.csv')
Gy_0

Gy_0_24 = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150nm0Gy_24h.csv')

# %%
#2 Gy* 
Gy_2 = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-24-2024/150nm2Gy-C.csv')
Gy_2_24 = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150nm2Gy_24h.csv')
Gy_2
# Out:
#             X [G]   Intensity
# 0     2508.969971  696.858398
# 1     2509.947021  697.858398
# 2     2510.924072  698.858398
# 3     2511.901123  696.858398
# 4     2512.878174  694.858398
# ...           ...         ...
# 2043  4505.062012 -327.141602
# 2044  4506.039063 -327.141602
# 2045  4507.016113 -325.141602
# 2046  4507.993164 -325.141602
# 2047  4508.970215 -324.141602
#
# [2048 rows x 2 columns]

# %%
#10 Gy *

Gy_10 = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-24-2024/150nm10Gy-B.csv')
Gy_10_24 = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150 nM 10Gy_24h_1.csv')

Gy_10
Gy_10_24
# Out:
#             X [G]   Intensity
# 0     2508.969971  478.081543
# 1     2509.947021  473.081543
# 2     2510.924072  464.081543
# 3     2511.901123  456.081543
# 4     2512.878174  453.081543
# ...           ...         ...
# 2043  4505.062012 -348.918457
# 2044  4506.039063 -348.918457
# 2045  4507.016113 -347.918457
# 2046  4507.993164 -344.918457
# 2047  4508.970215 -343.918457
#
# [2048 rows x 2 columns]

# %%
#15 Gy *

Gy_15 = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-24-2024/150nm15Gy-B.csv')
Gy_15_24 = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150 nM 15Gy_24h_2.csv')

# %%
#20 Gy * 

Gy_20 = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-24-2024/150nm20Gy-B.csv')
Gy_20_24 = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150 nM 20Gy_24h_1.csv')

Gy_20
# Out:
#             X [G]   Intensity
# 0     2508.969971  646.083496
# 1     2509.947021  647.083496
# 2     2510.924072  650.083496
# 3     2511.901123  654.083496
# 4     2512.878174  657.083496
# ...           ...         ...
# 2043  4505.062012 -345.916504
# 2044  4506.039063 -341.916504
# 2045  4507.016113 -338.916504
# 2046  4507.993164 -336.916504
# 2047  4508.970215 -333.916504
#
# [2048 rows x 2 columns]

# %% [markdown]
# Dose-Response Modeling:
# Develop a model relating EPR signal changes to radiation dose. Determine the linear range and sensitivity of the FMX nanoparticle system for dose estimation.
#
# Validation and Error Analysis:
# Compare estimated doses from the FMX system to known delivered doses. Calculate error margins and assess the accuracy of the nanoparticle-based dosimetry method.

# %% [markdown]
# Visualization:
# Create graphs showing the relationship between FMX concentration, radiation dose, and EPR signal intensity. Generate plots comparing estimated vs. actual doses.

# %%
colors = ['red', 'blue']  # Adjust colors as needed


# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_0, Gy_0_24] ):
  x_data = df['X [G]']
  y_data = df['Intensity']

  # Set custom labels for legend entries
  label_1 = "0 Hours"  # Replace with your desired label for the first DataFrame
  label_2 = " 24 Hours"  # Replace with your desired label for the second DataFrame
  plt.plot(x_data, y_data, label=label_1 if i == 0 else label_2, color=colors[i])  # Use conditional expression for labels

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('0 Gy w/o Asc')

# Add legend
plt.legend()

# %%
colors = ['red', 'blue']  # Adjust colors as needed


# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_2, Gy_2_24] ):
  x_data = df['X [G]']
  y_data = df['Intensity']

  # Set custom labels for legend entries
  label_1 = "0 Hours"  # Replace with your desired label for the first DataFrame
  label_2 = " 24 Hours"  # Replace with your desired label for the second DataFrame
  plt.plot(x_data, y_data, label=label_1 if i == 0 else label_2, color=colors[i])  # Use conditional expression for labels

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('2 Gy w/o Asc')

# Add legend
plt.legend()

# %%
#10 Gy 
colors = ['red', 'blue']  # Adjust colors as needed


# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_10, Gy_10_24] ):
  x_data = df['X [G]']
  y_data = df['Intensity']

  # Set custom labels for legend entries
  label_1 = "0 Hours"  # Replace with your desired label for the first DataFrame
  label_2 = " 24 Hours"  # Replace with your desired label for the second DataFrame
  plt.plot(x_data, y_data, label=label_1 if i == 0 else label_2, color=colors[i])  # Use conditional expression for labels

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('10 Gy w/o Asc')

# Add legend
plt.legend()

# %%
#15 Gy 
colors = ['red', 'blue']  # Adjust colors as needed


# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_15, Gy_15_24] ):
  x_data = df['X [G]']
  y_data = df['Intensity']

  # Set custom labels for legend entries
  label_1 = "0 Hours"  # Replace with your desired label for the first DataFrame
  label_2 = " 24 Hours"  # Replace with your desired label for the second DataFrame
  plt.plot(x_data, y_data, label=label_1 if i == 0 else label_2, color=colors[i])  # Use conditional expression for labels

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('15 Gy w/o Asc')

# Add legend
plt.legend()

# %%
#20 Gy 
colors = ['red', 'blue']  # Adjust colors as needed


# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_20, Gy_20_24] ):
  x_data = df['X [G]']
  y_data = df['Intensity']

  # Set custom labels for legend entries
  label_1 = "0 Hours"  # Replace with your desired label for the first DataFrame
  label_2 = " 24 Hours"  # Replace with your desired label for the second DataFrame
  plt.plot(x_data, y_data, label=label_1 if i == 0 else label_2, color=colors[i])  # Use conditional expression for labels

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('20 Gy w/o Asc')

# Add legend
plt.legend()

# %%
colors = ['red', 'blue', 'yellow', 'green', 'black']  # Adjust colors as needed

# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_0, Gy_2, Gy_10, Gy_15, Gy_20] ):
  x_data = df['X [G]']
  y_data = df['Intensity']


  # Extract label from DataFrame name (assuming names are descriptive)
  Gy_0.name = "0 Gy"  # Assign a name to the first DataFrame
  Gy_2.name = "2 Gy"  # Assign a name to the second DataFrame
  Gy_10.name = "10 Gy"
  Gy_15.name = "15 Gy"
  Gy_20.name = "20 Gy"
  label = df.name  # Assuming DataFrame names are in the format "Gy_XX"
  

  plt.plot(x_data, y_data, label=label, color=colors[i])  # Use DataFrame name as label

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('0 Hours Combined w/o Asc')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
colors = ['red', 'blue', 'yellow', 'green', 'black']  # Adjust colors as needed

# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_0_24, Gy_2_24, Gy_10_24, Gy_15_24, Gy_20_24] ):
  x_data = df['X [G]']
  y_data = df['Intensity']


  # Extract label from DataFrame name (assuming names are descriptive)
  Gy_0_24.name = "0 Gy"  # Assign a name to the first DataFrame
  Gy_2_24.name = "2 Gy"  # Assign a name to the second DataFrame
  Gy_10_24.name = "10 Gy"
  Gy_15_24.name = "15 Gy"
  Gy_20_24.name = "20 Gy"
  label = df.name  # Assuming DataFrame names are in the format "Gy_XX"
  

  plt.plot(x_data, y_data, label=label, color=colors[i])  # Use DataFrame name as label

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('24 Hours Combined w/o Asc')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
#OK OK LETS SEEEEEEEEEEE

Gy_0_Asc = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150nm0GyAsc.csv')
Gy_0_Asc_24 = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150nm0Gy_24h.csv')

colors = ['red', 'blue']  # Adjust colors as needed


# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_0_Asc_24, Gy_0_Asc] ):
  x_data = df['X [G]']
  y_data = df['Intensity']

  # Set custom labels for legend entries
  label_1 = "0 Hours"  # Replace with your desired label for the first DataFrame
  label_2 = " 24 Hours"  # Replace with your desired label for the second DataFrame
  plt.plot(x_data, y_data, label=label_1 if i == 0 else label_2, color=colors[i])  # Use conditional expression for labels

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('0 Gy w/ Asc')

# Add legend
plt.legend()

# %%
Gy_2_Asc = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150nm2Gy_Asc.csv')
Gy_2_Asc_24 = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150nm2Gy_24h.csv')

colors = ['red', 'blue']  # Adjust colors as needed


# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_2_Asc_24, Gy_2_Asc] ):
  x_data = df['X [G]']
  y_data = df['Intensity']

  # Set custom labels for legend entries
  label_2 = "24 Hours"  # Replace with your desired label for the first DataFrame
  label_1 = " 0 Hours"  # Replace with your desired label for the second DataFrame
  plt.plot(x_data, y_data, label=label_1 if i == 0 else label_2, color=colors[i])  # Use conditional expression for labels

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('2 Gy w/ Asc')

# Add legend
plt.legend()

# %%
Gy_10_Asc = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150 nM 10Gy Asc_1.csv')
Gy_10_Asc_24 = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150 nM 10Gy_24h_1.csv')

colors = ['red', 'blue']  # Adjust colors as needed


# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_10_Asc_24, Gy_10_Asc] ):
  x_data = df['X [G]']
  y_data = df['Intensity']

  # Set custom labels for legend entries
  label_2 = "24 Hours"  # Replace with your desired label for the first DataFrame
  label_1 = " 0 Hours"  # Replace with your desired label for the second DataFrame
  plt.plot(x_data, y_data, label=label_1 if i == 0 else label_2, color=colors[i])  # Use conditional expression for labels

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('10 Gy w/ Asc')

# Add legend
plt.legend()

# %%
Gy_15_Asc = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150 nM 15Gy Asc_2.csv')
Gy_15_Asc_24 = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150 nM 15Gy_24h_2.csv')

colors = ['red', 'blue']  # Adjust colors as needed


# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_15_Asc_24, Gy_15_Asc] ):
  x_data = df['X [G]']
  y_data = df['Intensity']

  # Set custom labels for legend entries
  label_1 = "0 Hours"  # Replace with your desired label for the first DataFrame
  label_2 = " 24 Hours"  # Replace with your desired label for the second DataFrame
  plt.plot(x_data, y_data, label=label_1 if i == 0 else label_2, color=colors[i])  # Use conditional expression for labels

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('15 Gy w/ Asc')

# Add legend
plt.legend()

# %%
Gy_20_Asc = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150 nM 20Gy Asc_1.csv')
Gy_20_Asc_24 = pd.read_csv('/Users/njengamacbook/Desktop/OneDrive_1_6-21-2024/150 nM 15Gy_24h_2.csv')


colors = ['red', 'blue']  # Adjust colors as needed


# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_20_Asc_24, Gy_20_Asc] ):
  x_data = df['X [G]']
  y_data = df['Intensity']

  # Set custom labels for legend entries
  label_2 = "24 Hours"  # Replace with your desired label for the first DataFrame
  label_1 = " 0 Hours"  # Replace with your desired label for the second DataFrame
  plt.plot(x_data, y_data, label=label_1 if i == 0 else label_2, color=colors[i])  # Use conditional expression for labels

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('20 Gy w/ Asc')

# Add legend
plt.legend()

# %%
colors = ['red', 'blue', 'yellow', 'green', 'black']  # Adjust colors as needed

# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_0_Asc, Gy_2_Asc, Gy_10_Asc, Gy_15_Asc, Gy_20_Asc] ):
  x_data = df['X [G]']
  y_data = df['Intensity']


  # Extract label from DataFrame name (assuming names are descriptive)
  Gy_0_Asc.name = "0 Gy"  # Assign a name to the first DataFrame
  Gy_2_Asc.name = "2 Gy"  # Assign a name to the second DataFrame
  Gy_10_Asc.name = "10 Gy"
  Gy_15_Asc.name = "15 Gy"
  Gy_20_Asc.name = "20 Gy"
  label = df.name  # Assuming DataFrame names are in the format "Gy_XX"
  

  plt.plot(x_data, y_data, label=label, color=colors[i])  # Use DataFrame name as label

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('0 Hours Combined w Asc')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
colors = ['red', 'blue', 'yellow', 'green', 'black']  # Adjust colors as needed

# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [Gy_0_Asc_24, Gy_2_Asc_24, Gy_10_Asc_24, Gy_15_Asc_24, Gy_20_Asc_24] ):
  x_data = df['X [G]']
  y_data = df['Intensity']


  # Extract label from DataFrame name (assuming names are descriptive)
  Gy_0_Asc_24.name = "0 Gy"  # Assign a name to the first DataFrame
  Gy_2_Asc_24.name = "2 Gy"  # Assign a name to the second DataFrame
  Gy_10_Asc_24.name = "10 Gy"
  Gy_15_Asc_24.name = "15 Gy"
  Gy_20_Asc_24.name = "20 Gy"
  label = df.name  # Assuming DataFrame names are in the format "Gy_XX"
  

  plt.plot(x_data, y_data, label=label, color=colors[i])  # Use DataFrame name as label

# Label the axes and add a title
plt.xlabel('Field Strength (G)')
plt.ylabel('Signal Intensity(A.U.)')
plt.title('24 Hours Combined w/ Asc')

# Add legend
plt.legend()

# Show the plot
plt.show()
